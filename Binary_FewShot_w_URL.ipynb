# %%
from openai import OpenAI
client = OpenAI(api_key="INSERT_KEY")  # Replace this!
# politifact_fake 432
# politifact_real 624
# gossipcop_fake 5323
# gossipcop_real 16817
# real 17441 75.2%
# fake 5755 24.8%

# %%
import pandas as pd
import openai
import time
import random
import re
import unicodedata
import json
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# ========================
# Configurable Parameters
# ========================
NUM_SAMPLES = 100
PRINT_SENTENCES = True
RANDOM_SEED = 42
MODEL = "gpt-3.5-turbo"
TEMPERATURE = 0
LLM_SEED = 42

# Pricing per 1K tokens
PRICING = {
    "gpt-4o": {"input": 0.0025, "output": 0.0100},
    "gpt-4-turbo": {"input": 0.0100, "output": 0.0300},
    "gpt-3.5-turbo": {"input": 0.0020, "output": 0.0020},
}

# Load and preprocess
def preprocess_text(text):
    text = unicodedata.normalize('NFKC', text)
    text = re.sub(r"[^a-zA-Z0-9.,!?\'\" ]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Load datasets
gossip_fake = pd.read_csv("gossipcop_fake.csv")
gossip_real = pd.read_csv("gossipcop_real.csv")

# Apply preprocessing
gossip_fake["title"] = gossip_fake["title"].apply(preprocess_text)
gossip_real["title"] = gossip_real["title"].apply(preprocess_text)

# Use raw news_url as "domain"
gossip_fake["domain"] = gossip_fake["news_url"]
gossip_real["domain"] = gossip_real["news_url"]

# Combine datasets
fake_data = gossip_fake[["title", "domain"]].values.tolist()
real_data = gossip_real[["title", "domain"]].values.tolist()

data = fake_data + real_data
labels = ["fake"] * len(fake_data) + ["real"] * len(real_data)

# Train-test split
random.seed(RANDOM_SEED)
indices = list(range(len(data)))
random.shuffle(indices)

train_indices = indices[:NUM_SAMPLES]
test_indices = indices[NUM_SAMPLES:NUM_SAMPLES * 2]

train_data = [data[i] for i in train_indices]
train_labels = [labels[i] for i in train_indices]

test_data = [data[i] for i in test_indices]
test_labels = [labels[i] for i in test_indices]

# Track usage and cost
token_usage = []
cost_usage = []


def classify_with_llm(text, domain, train_data, train_labels):
    """Few-shot LLM classification with JSON output."""
    
    training_examples = "\n".join(
        [f'- Headline: "{headline}"\n  Domain: {url}\n  → {label.lower()}'
         for (headline, url), label in zip(train_data, train_labels)]
    )

    system_message = {
        "role": "system",
        "content": (
            "You are a fake news classification assistant. "
            "Your job is to analyze a news headline and decide whether it is real or fake, based on patterns and domains.\n"
            "You must respond in this JSON format: {\"label\": \"real\"} or {\"label\": \"fake\"}.\n"
            "Do not include any extra explanation or text."
        )
    }

    user_prompt = f"""
    ## **Classification Rules**
    **✅ Real News (Fact-Based)**
    - Reports **actual events, official statements, or verifiable facts**.
    - Includes politics, entertainment, and sports **if they report real events**.
    - Headlines about **movies, music, or lifestyle topics** are typically **Real** unless they contain false claims.

    **❌ Fake News (Misleading)**
    - Includes **false, exaggerated, or misleading claims**.
    - **Viral rumors, unverified social media posts, and hoaxes** are Fake.
    - Political or celebrity gossip **without proof** should be classified as Fake.
    
    ## **Handling Special Cases**
    - **Social media reactions alone do not confirm truth** → Fake.
    - **A shocking event can still be Real if verifiable**.
    - **Lifestyle and entertainment news is Real unless it contains false information**.

    ## **How to Respond**
    - **Output only:** "Real" or "Fake" (no explanations).
    - If uncertain, classify based on **verifiable facts**.
    
    ##**Domain Handling**
    - Look for subtle differences in how the URL is structured that may hint at a source’s reliability

Below are 100 examples with their associated domains (i.e., full URLs). Learn from these patterns:

{training_examples}

---

Now classify the headline below:

Headline: "{text}"  
Domain: {domain}

Respond in JSON format:
{{"label": "real"}} or {{"label": "fake"}} 


"""

    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                system_message,
                {"role": "user", "content": user_prompt}
            ],
            max_tokens=20,
            temperature=TEMPERATURE,
            seed=LLM_SEED
        )

        usage = response.usage
        token_usage.append(usage.total_tokens)
        cost = (
            (usage.prompt_tokens / 1000) * PRICING[MODEL]["input"] +
            (usage.completion_tokens / 1000) * PRICING[MODEL]["output"]
        )
        cost_usage.append(cost)

        raw_output = response.choices[0].message.content.strip()

        try:
            parsed = json.loads(raw_output)
            label = parsed.get("label", "").lower()
            if label in {"real", "fake"}:
                return label
            else:
                print("⚠️ Invalid label in JSON:", raw_output)
                return "error"
        except json.JSONDecodeError:
            print("⚠️ JSON parsing error. Raw response:", raw_output)
            return "error"

    except Exception as e:
        print(f"Error during API call: {e}")
        return "error"

# Prediction loop
predictions = []
start_time = time.time()

for i, (headline, domain) in enumerate(test_data):
    pred = classify_with_llm(headline, domain, train_data, train_labels)
    predictions.append(pred)

    if PRINT_SENTENCES:
        print(f"Sentence: {headline}\nDomain: {domain}\nPredicted: {pred} | Actual: {test_labels[i]}\n")

# Evaluation
total_time = time.time() - start_time
total_tokens = sum(token_usage)
avg_tokens_per_article = total_tokens / len(test_data)
total_cost = sum(cost_usage)
cost_per_classification = total_cost / len(test_data)

accuracy = accuracy_score(test_labels, predictions)
precision, recall, f1, _ = precision_recall_fscore_support(test_labels, predictions, average='macro', zero_division=0)

eval_results = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1-score": f1,
    "Processing Time (s)": total_time,
    "Total Cost ($)": total_cost,
    "Cost per Classification ($)": cost_per_classification,
    "Total Tokens Used": total_tokens,
    "Average Tokens per Article": avg_tokens_per_article,
}

print("\nEvaluation Metrics:")
for key, value in eval_results.items():
    print(f"{key}: {value:.6f}")
# Out:
# Sentence: Secret in Their Eyes
# Domain: en.wikipedia.org/wiki/Secret_in_Their_Eyes
# Predicted: real | Actual: fake
#
# Sentence: Kim Kardashian and Katy Perry Hang Out on Taylor Swift Reputation Release Day
# Domain: https://www.elle.com/culture/celebrities/a13521386/kim-kardashian-north-west-at-katy-perry-witness-concert/
# Predicted: real | Actual: real
#
# Sentence: Jamie Lynn Spears
# Domain: https://en.wikipedia.org/wiki/Jamie_Lynn_Spears
# Predicted: real | Actual: real
#
# Sentence: Royal complexion Meghan Markles PERFECT SKIN secrets revealed by skin care expert
# Domain: https://www.express.co.uk/news/royal/1041414/Meghan-Markle-news-secrets-duchess-of-sussex-skin-latest-royal-news
# Predicted: fake | Actual: real
#
# Sentence: Kim Kardashian teases family Christmas card like an advent calendar
# Domain: https://www.nickiswift.com/98759/kim-kardashian-teases-family-christmas-card-like-advent-calendar/
# Predicted: real | Actual: real
#
# Sentence: Did Issa Rae Turn Drake Down At Golden Globes After Party?
# Domain: https://blackamericaweb.com/2018/01/12/did-issa-rae-turn-drake-down-at-golden-globes-after-party/
# Predicted: real | Actual: real
#
# Sentence: Mystery Restaurant Accidentally Leaks Hilarious Notes About Its Guests
# Domain: https://www.eater.com/2017/7/10/15947070/restaurant-guest-notes-leak-opentable
# Predicted: real | Actual: real
#
# Sentence: Justin Bieber Still Reeling From Selena Gomez Split Is He Searching For A New Love To Replace Her?
# Domain: hollywoodlife.com/2018/05/17/justin-bieber-selena-gomez-split-is-he-ready-for-love-again/
# Predicted: fake | Actual: fake
#
# Sentence: Nikki Bella Is "Really Disappointed" in Brie for Asking Daniel Bryan to Put in a Good Word for Her at WWE Watch!
# Domain: http://www.newslocker.com/en-us/news/celebrity/nikki-bella-is-really-disappointed-in-brie-for-asking-daniel-bryan-to-put-in-a-good-word-for-her-at-wwe-watch/
# Predicted: real | Actual: real
#
# Sentence: Kate Middleton Joins Royal Family at Easter Service Days Before Due Date
# Domain: https://www.longroom.com/discussion/958011/kate-middleton-joins-royal-family-at-easter-service-days-before-due-date
# Predicted: real | Actual: real
#
# Sentence: Prince's 'Deliverance' EP Removed From Streaming Services
# Domain: https://www.billboard.com/articles/columns/pop/7767704/prince-deliverance-ep-unreleased-material-removed
# Predicted: real | Actual: real
#
# Sentence: Portia de Rossi Explains Why She Quit Acting
# Domain: https://www.etonline.com/portia-de-rossi-explains-why-she-quit-acting-102365
# Predicted: real | Actual: real
#
# Sentence: Caitlyn Jenner Is Not Joining Dancing With the Stars
# Domain: www.usmagazine.com/entertainment/news/caitlyn-jenner-is-not-joining-dancing-with-the-stars/
# Predicted: real | Actual: fake
#
# Sentence: 'Who wore it best?' Kate Hudson channels Leonardo DiCaprio's '90s hair
# Domain: https://www.today.com/style/who-wore-it-best-kate-hudson-channels-leonardo-dicaprio-s-t119839
# Predicted: real | Actual: real
#
# Sentence: Penelope Cruz and Javier Bardem Received Equal Pay for Their Film 'Everybody Knows'
# Domain: https://www.etonline.com/penelope-cruz-and-javier-bardem-received-equal-pay-for-their-film-everybody-knows-101954
# Predicted: real | Actual: real
#
# Sentence: Julia Stiles marries fiance Preston J. Cook in 'shotgun wedding'
# Domain: https://www.today.com/popculture/julia-stiles-marries-fiance-preston-j-cook-shotgun-wedding-t116746
# Predicted: real | Actual: real
#
# Sentence: Pinks Carpool Karaoke Takes a Detour for Some UpsideDown Singing
# Domain: https://www.vulture.com/2017/11/pinks-carpool-karaoke-upside-down-singing.html
# Predicted: real | Actual: real
#
# Sentence: Is Carey Mulligan Pregnant With Baby No. 2?
# Domain: https://www.usmagazine.com/celebrity-moms/news/is-carey-mulligan-pregnant-with-baby-no-2-w485652/
# Predicted: real | Actual: real
#
# Sentence: Robert Pattinson, Chris Pratt More Stars Who Dream of Going Off the Grid
# Domain: http://bojtv.com/robert-pattinson-chris-pratt-more-stars-who-dream-of-going-off-the-grid/
# Predicted: real | Actual: real
#
# Sentence: Jodie Whittaker named the first female "Doctor Who"
# Domain: https://www.cbsnews.com/news/jodie-whittaker-named-the-first-female-doctor-who/
# Predicted: real | Actual: real
#
# Sentence: See Lauren Conrad's Adorable Christmas Card Starring Her 5MonthOld Son Liam James!
# Domain: https://people.com/parents/lauren-conrad-liam-james-tell-first-christmas-card/
# Predicted: real | Actual: real
#
# Sentence: Jennifer Aniston reveals the truth about her divorce from Justin Theroux
# Domain: www.newidea.com.au/the-truth-about-jennifer-aniston-justin-theroux-divorce
# Predicted: fake | Actual: fake
#
# Sentence: Jesse Williams Ordered to Pay 50,000 a Month in Child Support
# Domain: https://people.com/tv/jesse-williams-ordered-to-pay-50000-a-month-in-child-support/
# Predicted: real | Actual: real
#
# Sentence: Melrose Place Star Josie Bissett Is Married! See Photos of the Outdoor Ceremony
# Domain: https://www.brides.com/story/melrose-place-star-josie-bissett-wedding-photos
# Predicted: real | Actual: real
#
# Sentence: Ariel Winter attacks tabloid's 'trash' story about her boyfriend
# Domain: https://www.usatoday.com/story/life/tv/2017/06/21/ariel-winter-attacks-tabloids-trash-story-her-boyfriend/103086196/
# Predicted: real | Actual: real
#
# Sentence: Kim Kardashian Sick Of Prince Harry, Meghan Markle "Royal Wedding Fever"?
# Domain: www.letsplayindex.com/videos/40911141-kim-kardashian-sick-of-prince-harry-meghan-markle-royal
# Predicted: fake | Actual: fake
#
# Sentence: ARod Spills All The Details On His Couples Workouts With Jennifer Lopez
# Domain: https://www.delish.com/food/a54846/a-rod-couples-workouts-jennifer-lopez/
# Predicted: real | Actual: real
#
# Sentence: Chadwick Boseman Surprised Black Panther Fans and We're So Emotional Right Now
# Domain: https://www.harpersbazaar.com/culture/film-tv/a19042479/chadwick-boseman-surprises-black-panther-fans/
# Predicted: real | Actual: real
#
# Sentence: Pregnant Jenny Mollen Shows Dramatic BeforeandAfter Baby Bump Photo
# Domain: https://article.wn.com/view/2017/08/27/Pregnant_Jenny_Mollen_Shows_Dramatic_BeforeandAfter_Baby_Bum/
# Predicted: real | Actual: real
#
# Sentence: According To Chrisley TV Show Watch Full Episodes
# Domain: https://www.usanetwork.com/accordingtochrisley
# Predicted: real | Actual: real
#
# Sentence: Is Halle Berry Dating Keanu Reeves?!
# Domain: extratv.com/2018/05/30/is-halle-berry-dating-keanu-reeves/
# Predicted: fake | Actual: fake
#
# Sentence: Kit Harington Marries Rose Leslie in Romantic Scotland Ceremony See the Photos!
# Domain: https://people.com/tv/kit-harington-rose-leslie-married-wedding-photos/
# Predicted: real | Actual: real
#
# Sentence: Padma Lakshmi Connects with Late Lover Teddy Forstmann on Hollywood Medium
# Domain: https://people.com/tv/padma-lakshmi-connects-late-lover-teddy-hollywood-medium/
# Predicted: real | Actual: real
#
# Sentence: Nicole 'Snooki' Polizzi Creates an Awkward Situation for Mike Sorrentino on 'Reunion Road Trip'
# Domain: https://popculture.com/reality-tv/2017/08/19/nicole-snooki-polizzi-mike-situation-sorrentino-mtv-reunion/
# Predicted: real | Actual: real
#
# Sentence: Billie Lourd Celebrates Her First Birthday Without Her Mom Carrie Fisher
# Domain: https://www.instyle.com/news/billie-lourd-birthday-without-carrie-fisher
# Predicted: real | Actual: real
#
# Sentence: Garrett Hedlund Gushes Over Mary J. Blige's 2018 Globe Nomination ...
# Domain: https://www.15minutenews.com/article/137442581/garrett-hedlund-gushes-over-mary-j-bliges-2018-globe-nomination-she-did-a-wonderful-job/
# Predicted: real | Actual: real
#
# Sentence: RHONY Bethenny Frankel and Ramona Singer compete for the same guy
# Domain: https://www.dailymail.co.uk/tvshowbiz/article-5943615/Bethenny-Frankel-Ramona-Singer-awkwardly-compete-guy-speed-dating-party-RHONY.html
# Predicted: real | Actual: real
#
# Sentence: Is Drake Referring To Bella Hadid Fling On "Finesse"?
# Domain: www.hotnewhiphop.com/is-drake-talking-about-bella-hadid-on-finesse-news.53907.html
# Predicted: real | Actual: fake
#
# Sentence: Celebrities show off Thanksgiving feasts and wish fans a happy holiday
# Domain: www.mirror.co.uk/3am/celebrity-news/celebrities-show-thanksgiving-feasts-wish-6909512
# Predicted: real | Actual: fake
#
# Sentence: How Carmelo Anthony justified allegedly cheating on La La
# Domain: https://pagesix.com/2017/04/18/how-carmelo-anthony-justified-allegedly-cheating-on-la-la/
# Predicted: real | Actual: real
#
# Sentence: Ryan Reynolds revealed his and Blake Lively's current favorite show, and same
# Domain: https://hellogiggles.com/celebrity/ryan-reynolds-blake-lively-favorite-show/
# Predicted: real | Actual: real
#
# Sentence: ATTN Juicy Couture Tracksuits Are Making a Comeback
# Domain: https://www.cosmopolitan.com/style-beauty/fashion/news/a59329/juicy-couture-tracksuit-making-a-comeback/
# Predicted: real | Actual: real
#
# Sentence: Inside the Fabulous First Year of George and Amal Clooney's Twins
# Domain: www.eonline.com/news/941636/inside-the-fabulous-first-year-of-george-and-amal-clooney-s-twins
# Predicted: real | Actual: fake
#
# Sentence: Prince dies at 57 How the news unfolded
# Domain: https://www.telegraph.co.uk/news/2016/04/21/prince-feared-dead-as-police-investigate-death-on-stars-paisley2/
# Predicted: real | Actual: real
#
# Sentence: Amanda Seyfried Is Adoring Life as a New Mom
# Domain: https://www.instyle.com/news/amanda-seyfried-mom-new-motherhood
# Predicted: real | Actual: real
#
# Sentence: Here Are All the Public Figures Whove Been Accused of Sexual Misconduct After Harvey Weinstein
# Domain: http://time.com/5015204/harvey-weinstein-scandal/
# Predicted: real | Actual: real
#
# Sentence: Melania Trump nudges Donald to remind him to raise his hand during National Anthem
# Domain: https://www.telegraph.co.uk/news/2017/04/17/melania-trump-nudges-donald-remind-raise-hand-national-anthem/
# Predicted: real | Actual: real
#
# Sentence: Cline Dion Has Blossomed Into a FullFledged Fashion Icon
# Domain: http://bojtv.com/celine-dion-has-blossomed-into-a-full-fledged-fashion-icon/
# Predicted: real | Actual: real
#
# Sentence: George and Amal Clooney hire 'baby bouncers' to protect newborn twins
# Domain: www.dailystar.co.uk/showbiz/621405/George-Amal-Clooney-hire-baby-bouncers-protect-newborn-twins-Alex-Ella
# Predicted: real | Actual: fake
#
# Sentence: Joan Rivers, Shonda Rhimes among Television Academy Hall of Fame inductees
# Domain: https://abcnews.go.com/Entertainment/joan-rivers-shonda-rhimes-television-academy-hall-fame/story?id=50463390
# Predicted: real | Actual: real
#
# Sentence: 10 Things You Absolutely Need to Know Before Getting a Spray Tan
# Domain: https://stylecaster.com/beauty/spray-tan-tips/
# Predicted: real | Actual: real
#
# Sentence: Categories video is Darren Aronofsky dating jennifer lawrence
# Domain: clipsg.com/cc/is-Darren-Aronofsky-dating-jennifer-lawrence
# Predicted: fake | Actual: fake
#
# Sentence: Police Arrest 2 Brothers For Murders Of 4 Women At Fairmont Terrace Apartments
# Domain: www.newson6.com/story/20998327/police-arrest-2-brothers-for-fairmont-terrace-quadruple-murder
# Predicted: real | Actual: fake
#
# Sentence: Every season of American Horror Story so far, ranked
# Domain: https://www.vox.com/culture/2018/9/12/17850994/american-horror-story-seasons-ranked-apocalypse
# Predicted: real | Actual: real
#
# Sentence: Meghan Markles Bucket List Reveals the Royals Surprising ToDos
# Domain: www.cheatsheet.com/health-fitness/meghan-markles-bucket-list-reveals-royals-surprising-to-dos.html/
# Predicted: real | Actual: fake
#
# Sentence: Jennifer Lopez Has a Beauty Pet Peeve Everyone Can Relate to
# Domain: http://nextdivas.com/2018/04/24/jennifer-lopez-has-a-beauty-pet-peeve-everyone-can-relate-to/
# Predicted: real | Actual: real
#
# Sentence: William H. Macy backstage at the SAG Awards 'It's hard to be a man these days'
# Domain: https://www.usatoday.com/story/life/people/2018/01/21/william-h-macy-backstage-sag-awards-its-hard-man-these-days/1052640001/
# Predicted: real | Actual: real
#
# Sentence: Beckham allegations from 'hacked and doctored emails'
# Domain: www.goal.com/en-us/news/david-beckham-allegations-deliberately-innacurate-says-spokesman-/9g7uk3r8nldk1nd2ouz4jupo1
# Predicted: real | Actual: fake
#
# Sentence: Robert Pattinson REVEALS the reason for taking therapy
# Domain: www.ibtimes.co.in/robert-pattinson-reveals-reason-taking-therapy-748262
# Predicted: real | Actual: fake
#
# Sentence: Harvey Weinstein news Academy expels embattled producer amid sexual assault allegations
# Domain: https://www.usatoday.com/story/life/movies/2017/10/14/oscars-board-expected-review-weinsteins-membership/764530001/
# Predicted: real | Actual: real
#
# Sentence: Caitlyn Jenner 'Wasn't Happy at First' About Kylie Jenner Becoming a Young Mom, Source Says Exclusive
# Domain: www.etonline.com/caitlyn-jenner-wasnt-happy-first-about-kylie-jenner-becoming-young-mom-source-says-exclusive-94534
# Predicted: real | Actual: fake
#
# Sentence: Kevin Feige Teases Black Panther Sequel and Spinoff Possibilities
# Domain: http://www.15minutenews.com/article/142881757/kevin-feige-teases-black-panther-sequel-and-spinoff-possibilities/
# Predicted: real | Actual: real
#
# Sentence: You and Selena Gomez Probably Have One Big Thing in Common
# Domain: www.teenvogue.com/story/selena-gomez-doctors-office
# Predicted: real | Actual: fake
#
# Sentence: A Timeline of Pippa Middleton and James Matthews Relationship
# Domain: https://www.townandcountrymag.com/society/politics/g9660632/pippa-middleton-james-matthews-relationship-timeline/
# Predicted: real | Actual: real
#
# Sentence: Ocean's 8 Review Roundup Did Sandra Bullock and Company Wow Critics?
# Domain: https://en.wikipedia.org/wiki/Ocean%27s_8
# Predicted: real | Actual: real
#
# Sentence: Judy Sheindlin
# Domain: https://en.wikipedia.org/wiki/Judy_Sheindlin
# Predicted: real | Actual: real
#
# Sentence: Golden Globes Red Carpet Veterans Vote for Reese Witherspoon, Nicole Kidman More Stars' Best Looks Ever!
# Domain: https://gossipbucket.com/e-online/1261026/golden-globes-red-carpet-veterans-vote-for-reese-witherspoon-nicole-kidman-more-stars-best-look/
# Predicted: real | Actual: real
#
# Sentence: Black Eyed Peas' Taboo claims Fergie turned down band reunion to work on her solo album
# Domain: https://www.dailymail.co.uk/tvshowbiz/article-6521121/Black-Eyed-Peas-Taboo-claims-Fergie-turned-band-reunion-work-solo-album.html
# Predicted: real | Actual: real
#
# Sentence: NBC Renews Will Grace for Season 3, Adds to Season 2 Episode Order
# Domain: https://variety.com/2018/tv/news/will-grace-nbc-season-3-renewal-1202729616/
# Predicted: real | Actual: real
#
# Sentence: Christina El Moussa Looks Totally Smitten on Dinner Date With New Boyfriend See the Pic!
# Domain: https://www.etonline.com/news/219782_christina_el_moussa_looks_totally_smitten_on_dinner_date_with_new_boyfriend
# Predicted: real | Actual: real
#
# Sentence: The top 21 Cyber Monday tech deals to scoop up today from 300 off the Surface Laptop 2 to 400 off a Sony 4K TV
# Domain: http://uk.businessinsider.com/best-cyber-monday-tech-deals-sales-2018
# Predicted: real | Actual: real
#
# Sentence: Dakota Meyer
# Domain: https://en.wikipedia.org/wiki/Dakota_Meyer
# Predicted: real | Actual: real
#
# Sentence: 'It's a Boy' Emilie de Ravin to Have a Baby Boy in Fall
# Domain: https://www.albawaba.com/entertainment/its-boy-emilie-de-ravin-have-baby-boy-fall-1152174
# Predicted: real | Actual: real
#
# Sentence: Jasper Gets Stuck in an Ambulance as Riots Break Out During King Robert's Blackout on The Royals
# Domain: https://www.longroom.com/discussion/950339/jasper-gets-stuck-in-an-ambulance-as-riots-break-out-during-king-roberts-blackout-on-the-royals
# Predicted: real | Actual: real
#
# Sentence: Erin Andrews gets married at picturesque wedding
# Domain: https://www.usatoday.com/story/sports/ftw/2017/06/25/erin-andrews-and-jarret-stoll-got-married-at-a-picturesque-wedding-ceremony-in-montana/103192352/
# Predicted: real | Actual: real
#
# Sentence: Emily Blunt
# Domain: https://en.wikipedia.org/wiki/Emily_Blunt
# Predicted: real | Actual: real
#
# Sentence: Justin Bieber asked Stephen Baldwin for Haileys hand
# Domain: https://pagesix.com/2018/07/10/justin-bieber-asked-stephen-baldwin-for-haileys-hand/
# Predicted: real | Actual: real
#
# Sentence: Emma Watson says working with Tom Hanks was a dream come true
# Domain: https://www.hindustantimes.com/hollywood/emma-watson-says-working-with-tom-hanks-was-a-dream-come-true/story-pg1vD9Q5x4qfvAtKjKFJtO.html
# Predicted: real | Actual: real
#
# Sentence: 9 Makeup Products With BuiltIn Sunscreen to Make Your Life Easier
# Domain: https://www.byrdie.com/makeup-with-spf
# Predicted: real | Actual: real
#
# Sentence: The 100 Season 5 Spoilers Octavias Redemption, New Interview
# Domain: https://tvline.com/2018/06/05/the-100-season-5-spoilers-octavia-redemption-arc-new-interview/
# Predicted: real | Actual: real
#
# Sentence: List of Marvel Cinematic Universe films
# Domain: https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films
# Predicted: real | Actual: real
#
# Sentence: Tori and Dean 11 Years, 5 Kids and All the Ups and Downs In Between
# Domain: https://people.com/tv/tori-and-dean-10-years-5-kids-and-all-the-ups-and-downs-in-between/
# Predicted: real | Actual: real
#
# Sentence: Mandy Moore on Why She Was Never Going to Be Britney Spears or Christina Aguilera
# Domain: https://www.etonline.com/mandy-moore-on-why-she-was-never-going-to-be-britney-spears-or-christina-aguilera-113310
# Predicted: real | Actual: real
#
# Sentence: 'This is McCarthyism!' Trump accuses Obama of 'wiretapping' his office before election
# Domain: www.theguardian.com/us-news/2017/mar/04/donald-trump-accuses-obama-of-wire-tapping-his-office-before-election
# Predicted: fake | Actual: fake
#
# Sentence: Bootleg Quaaludes, Crabs Shooting Ashes From a Cannon 7 Bizarre Revelations From Johnny Depp's ...
# Domain: https://article.wn.com/view/2018/06/21/Bootleg_Quaaludes_Crabs_Shooting_Ashes_From_a_Cannon_7_Bizar/
# Predicted: real | Actual: real
#
# Sentence: Ciara Russell Wilson Share Pics From Their Amazing Trip to China Check Out Their Family Photos!
# Domain: https://www.etonline.com/news/222301_ciara_russell_wilson_share_pics_from_their_amazing_trip_to_china_check_out_their_family_photos
# Predicted: real | Actual: real
#
# Sentence: Busy Philipps Just Dyed Michelle Williams' Hair Pink on Instagram
# Domain: https://www.glamour.com/story/busy-philipps-dyed-michelle-williams-hair-pink-instagram
# Predicted: real | Actual: real
#
# Sentence: Shakira Kicks Off Momentous U.S. Tour in Chicago After 7Year Wait 'I've Been Dreaming About This Moment'
# Domain: https://www.billboard.com/articles/columns/latin/8468666/shakira-north-american-el-dorado-tour-live-review
# Predicted: real | Actual: real
#
# Sentence: Kim Kardashian, Kanye West Snubbed By Kate Middleton And Prince William Report Debunked
# Domain: www.travelerstoday.com/articles/45288/20170411/kim-kardashian-kanye-west-snubbed-kate-middleton-prince-william-report.htm
# Predicted: fake | Actual: fake
#
# Sentence: You're the Worst Season 4, Now With More Crack and Ghosting Fallout
# Domain: https://en.paperblog.com/you-re-the-worst-season-4-now-with-more-crack-and-ghosting-fallout-1720837/
# Predicted: real | Actual: real
#
# Sentence: 'Riverdale' Showrunner on Archie's Fate After That Whirlwind Trial
# Domain: https://www.thewrap.com/riverdale-showrunner-on-archies-fate-after-whirlwind-trial-in-season-3-premiere/
# Predicted: real | Actual: real
#
# Sentence: Tyga Why Hes Obsessed With Dating Kylie Jenner LookAlikes, But None Can Take Her Place
# Domain: hollywoodlife.com/2018/02/06/tyga-dating-kylie-jenner-look-alike-reason-split/
# Predicted: fake | Actual: fake
#
# Sentence: Caitlyn Jenner Already Set For Second Boob Job
# Domain: www.nationalenquirer.com/photos/caitlyn-jenner-breasts-boob-job/
# Predicted: fake | Actual: fake
#
# Sentence: Demi Lovato 'Beat Shazam' Episode Pulled From Fox Schedule After Overdose Report
# Domain: https://www.billboard.com/articles/news/8466944/demi-lovato-beat-shazam-canceled-overdose
# Predicted: real | Actual: real
#
# Sentence: Danny Amendola Raves About Loving GF Olivia Culpo Ahead Of Super Bowl Im Lucky To Have Her
# Domain: https://hollywoodlife.com/2018/01/31/danny-amendola-loves-olivia-culpo-dating-realtionship-lucky/
# Predicted: real | Actual: real
#
# Sentence: Onion Ring Instagrams and Other Secret Celebrity Accounts
# Domain: https://cookiesandsangria.com/2017/06/16/onion-ring-instagrams-and-other-secret-celebrity-accounts/
# Predicted: real | Actual: real
#
# Sentence: Grammy Chief Announces Task Force to Improve Female Advancement Variety
# Domain: https://variety.com/2018/music/news/grammy-chief-neil-portnow-announces-task-force-to-improve-female-advancement-1202684850/
# Predicted: real | Actual: real
#
# Sentence: Lady Gaga Nude Photo Hot or Not? NSFW
# Domain: https://www.vibe.com/2013/07/lady-gaga-nude-photo-hot-or-not-nsfw-2
# Predicted: fake | Actual: real
#
# Sentence: All the Clues Meghan Markle Has Picked Ralph Russo to Design Her Wedding Dress
# Domain: https://theworldnews.net/us-news/all-the-clues-meghan-markle-has-picked-ralph-russo-to-design-her-wedding-dress
# Predicted: real | Actual: real
#
# Sentence: Kanye West Leaves Kim Kardashian After a Massive Fight "He Stormed Off, Leaving Kim in Tears" EXCLUSIVE
# Domain: www.intouchweekly.com/posts/kanye-west-leaves-kim-kardashian-159645
# Predicted: fake | Actual: fake
#
#
# Evaluation Metrics:
# Accuracy: 0.860000
# Precision: 0.848485
# Recall: 0.714452
# F1-score: 0.751949
# Processing Time (s): 56.173787
# Total Cost ($): 1.275788
# Cost per Classification ($): 0.012758
# Total Tokens Used: 637894.000000
# Average Tokens per Article: 6378.940000

# %%
# GPT 4O
Evaluation Metrics:
Accuracy: 0.900000
Precision: 0.873984
Recall: 0.821678
F1-score: 0.843750
Processing Time (s): 79.894459
Total Cost ($): 1.584060
Cost per Classification ($): 0.015841
Total Tokens Used: 631524.000000
Average Tokens per Article: 6315.240000


# GPT 4-TURBO
Evaluation Metrics:
Accuracy: 0.830000
Precision: 0.752400
Recall: 0.760490
F1-score: 0.756272
Processing Time (s): 112.509617
Total Cost ($): 6.392940
Cost per Classification ($): 0.063929
Total Tokens Used: 637894.000000
Average Tokens per Article: 6378.940000

# GPT 3.5-TURBO
Evaluation Metrics:
Accuracy: 0.860000
Precision: 0.848485
Recall: 0.714452
F1-score: 0.751949
Processing Time (s): 62.184701
Total Cost ($): 1.275788
Cost per Classification ($): 0.012758
Total Tokens Used: 637894.000000
Average Tokens per Article: 6378.940000

# %%
##################
# CLASSIFICATION #
##################
Accuracy = Number of correct predictions/Total predictions

Precision = TP / (TP+ FP)
# How many predicted fake headlines are actually fake
# Low precision means model is mislabelling too many real headlines as fake

Recall = TP / (TP + FN)
# How many fake headlines were correctly identified as fake
# Low recall means model is letting too many fake news headlines slip through as real

F1 = 2 X (Precision x Recall)/(Precision + Recall) #Harmonic mean of precision and recall

##############
# EFFICIENCY #
##############
Tokens per article = How many tokens the LLM processes per request = Total tokens/Number of Sentences
Cost per classification = Total cost/Number of Sentences

#############
# TECHNICAL #
#############
Processing time = How long it takes to run
Cross-dataset performance = Compare performance on different datasets
