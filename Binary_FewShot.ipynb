# %%
from openai import OpenAI
client = OpenAI(api_key="INSERT_KEY")  # Replace this!
# politifact_fake 432
# politifact_real 624
# gossipcop_fake 5323
# gossipcop_real 16817
# real 17441 75.2%
# fake 5755 24.8%

# %%
import pandas as pd
import openai
import time
import random
import re
import unicodedata
import json
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# ========================
# Configurable Parameters
# ========================
NUM_SAMPLES = 100  # Number of samples for training and testing
PRINT_SENTENCES = True
RANDOM_SEED = 42
MODEL = "gpt-3.5-turbo"
TEMPERATURE = 0
LLM_SEED = 42
USE_FULL_DATASET = False

# Set random seed
random.seed(RANDOM_SEED)

# Pricing details (per 1K tokens)
PRICING = {
    "gpt-4o": {"input": 0.0025, "output": 0.0100},
    "gpt-4-turbo": {"input": 0.0100, "output": 0.0300},
    "gpt-3.5-turbo": {"input": 0.0020, "output": 0.0020},
}

# Load datasets
politifact_fake = pd.read_csv("politifact_fake.csv")["title"].dropna()
politifact_real = pd.read_csv("politifact_real.csv")["title"].dropna()
gossipcop_fake = pd.read_csv("gossipcop_fake.csv")["title"].dropna()
gossipcop_real = pd.read_csv("gossipcop_real.csv")["title"].dropna()

# Preprocessing function
def preprocess_text(text):
    text = unicodedata.normalize('NFKC', text)
    text = re.sub(r"[^a-zA-Z0-9.,!?\'\" ]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Preprocess and merge data
data = (
    politifact_fake.apply(preprocess_text).tolist() +
    politifact_real.apply(preprocess_text).tolist() +
    gossipcop_fake.apply(preprocess_text).tolist() +
    gossipcop_real.apply(preprocess_text).tolist()
)

labels = (
    ["fake"] * len(politifact_fake) +
    ["real"] * len(politifact_real) +
    ["fake"] * len(gossipcop_fake) +
    ["real"] * len(gossipcop_real)
)

# Train-test split (100 each)
indices = list(range(len(data)))
random.shuffle(indices)

train_indices = indices[:NUM_SAMPLES]
test_indices = indices[NUM_SAMPLES:NUM_SAMPLES * 2]

train_data = [data[i] for i in train_indices]
train_labels = [labels[i] for i in train_indices]

test_data = [data[i] for i in test_indices]
test_labels = [labels[i] for i in test_indices]

token_usage = []
cost_usage = []

def classify_with_llm(text, train_data, train_labels):
    """Few-shot LLM classification with system message and JSON output (no domain)."""

    training_examples = "\n".join(
        [f'- Headline: "{headline}" → {label.lower()}'
         for headline, label in zip(train_data, train_labels)]
    )

    system_message = {
        "role": "system",
        "content": (
            "You are a fake news classification assistant. "
            "Your job is to analyze a news headline and decide whether it is real or fake.\n"
            "You must respond in this JSON format: {\"label\": \"real\"} or {\"label\": \"fake\"}.\n"
            "Do not include any extra explanation or text."
        )
    }

    user_prompt = f"""
## **Classification Rules**
**✅ Real News (Fact-Based)**
- Reports **actual events, official statements, or verifiable facts**.
- Includes politics, entertainment, and sports **if they report real events**.
- Headlines about **movies, music, or lifestyle topics** are typically **Real** unless they contain false claims.

**❌ Fake News (Misleading)**
- Includes **false, exaggerated, or misleading claims**.
- **Viral rumors, unverified social media posts, and hoaxes** are Fake.
- Political or celebrity gossip **without proof** should be classified as Fake.

## **Handling Special Cases**
- **Social media reactions alone do not confirm truth** → Fake.
- **A shocking event can still be Real if verifiable**.
- **Lifestyle and entertainment news is Real unless it contains false information**.

## **How to Respond**
- **Output only** a JSON object: {{"label": "real"}} or {{"label": "fake"}}.
- Do not include any explanation, commentary, or formatting.

---

Below are 100 labeled examples to learn from:

{training_examples}

---

Now classify the headline below:

Headline: "{text}"

Respond in JSON format:
{{"label": "real"}} or {{"label": "fake"}}
""".strip()

    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                system_message,
                {"role": "user", "content": user_prompt}
            ],
            max_tokens=20,
            temperature=TEMPERATURE,
            seed=LLM_SEED
        )

        usage = response.usage
        token_usage.append(usage.total_tokens)

        cost = (
            (usage.prompt_tokens / 1000) * PRICING[MODEL]["input"] +
            (usage.completion_tokens / 1000) * PRICING[MODEL]["output"]
        )
        cost_usage.append(cost)

        raw_output = response.choices[0].message.content.strip()

        try:
            parsed = json.loads(raw_output)
            label = parsed.get("label", "").lower()
            if label in {"real", "fake"}:
                return label
            else:
                print("⚠️ Invalid label in JSON:", raw_output)
                return "error"
        except json.JSONDecodeError:
            print("⚠️ JSON parsing error. Raw response:", raw_output)
            return "error"

    except Exception as e:
        print(f"❌ Error during API call: {e}")
        return "error"

# Prediction loop
predictions = []
start_time = time.time()

for i, text in enumerate(test_data):
    pred = classify_with_llm(text, train_data, train_labels)
    predictions.append(pred)

    if PRINT_SENTENCES:
        print(f"Sentence: {text}\nPredicted: {pred} | Actual: {test_labels[i]}\n")

# Time and cost
total_time = time.time() - start_time
total_tokens = sum(token_usage)
avg_tokens_per_article = total_tokens / len(test_data)
total_cost = sum(cost_usage)
cost_per_classification = total_cost / len(test_data)

# Evaluation
accuracy = accuracy_score(test_labels, predictions)
precision, recall, f1, _ = precision_recall_fscore_support(test_labels, predictions, average='macro', zero_division=0)

eval_results = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1-score": f1,
    "Processing Time (s)": total_time,
    "Total Cost ($)": total_cost,
    "Cost per Classification ($)": cost_per_classification,
    "Total Tokens Used": total_tokens,
    "Average Tokens per Article": avg_tokens_per_article,
}

print("\nEvaluation Metrics:")
for key, value in eval_results.items():
    print(f"{key}: {value:.6f}")
# Out:
# Sentence: Justin Bieber Tattoo Guide All The Sorry Stars Designs What They Mean
# Predicted: real | Actual: real
#
# Sentence: List of awards and nominations received by Emma Stone
# Predicted: real | Actual: real
#
# Sentence: Christina Aguilera To Dump Matthew Rutler And Date Colin Farrell Instead
# Predicted: fake | Actual: fake
#
# Sentence: Maci Bookout Granted 2 Year Restraining Order Against Ryan Edwards
# Predicted: real | Actual: real
#
# Sentence: Stephen Curry
# Predicted: real | Actual: real
#
# Sentence: The 1 Surprising Reason John Oliver Wouldnt Blame Meghan Markle for Calling Off the Royal Wedding
# Predicted: real | Actual: real
#
# Sentence: 8 of the worlds most expensive wedding dresses
# Predicted: real | Actual: real
#
# Sentence: Kristin Cavallari tells Jay Cutler 'I'm with you because I love you not because I need you.'
# Predicted: real | Actual: real
#
# Sentence: Fixer Upper Is Ending. What Is Chip and Joanna Gaines' Net Worth?
# Predicted: real | Actual: real
#
# Sentence: Weird marriage rules Tom Cruise imposed on Katie Holmes 'Silence during labour' and 'no public dating' after their split
# Predicted: real | Actual: fake
#
# Sentence: Last chance to vote in this year's TV Scoop Awards Pressparty
# Predicted: real | Actual: real
#
# Sentence: Andy Roddick career statistics
# Predicted: real | Actual: real
#
# Sentence: Alex Rodriguez Net Worth
# Predicted: real | Actual: real
#
# Sentence: Crazy ExGirlfriend season 4
# Predicted: real | Actual: real
#
# Sentence: Tina Fey Making Mean Girls Sequel Without Lindsay Lohan
# Predicted: real | Actual: fake
#
# Sentence: Norvell Presents "Dancing With The Stars" Product Line
# Predicted: real | Actual: real
#
# Sentence: Categorias de vdeos Radar Online
# Predicted: real | Actual: fake
#
# Sentence: Jennifer Aniston About Justin Theroux s Sauna Addiction
# Predicted: real | Actual: fake
#
# Sentence: Selena Gomez Pissed Charlie Puth Went Public With Romance She Wants Dating Life Under Wraps
# Predicted: fake | Actual: fake
#
# Sentence: 2018 MTV Movie TV Awards
# Predicted: real | Actual: real
#
# Sentence: Linkin Park and Friends Celebrate Life in Honor of Chester Bennington
# Predicted: real | Actual: real
#
# Sentence: Cardi B Steals the Spotlight in OvertheTop Moschino Ensemble at the 2018 Met Gala
# Predicted: real | Actual: real
#
# Sentence: Think the Kardashians started off the cycling shorts trend? It was actually Princess Diana
# Predicted: real | Actual: real
#
# Sentence: 4 Exercises Tracy Anderson Loves To Do First Thing in the Morning
# Predicted: real | Actual: real
#
# Sentence: Watch Khloe Kardashian Sound Off On Tristan Thompson Cheating Scandal After Giving Birth
# Predicted: real | Actual: real
#
# Sentence: Super Bowl XLI
# Predicted: real | Actual: real
#
# Sentence: Ordeal by Innocence producers explain decision to reshoot BBC drama following Ed Westwick allegations
# Predicted: real | Actual: real
#
# Sentence: Paris Jackson Strips Down To Play Cards
# Predicted: real | Actual: fake
#
# Sentence: 'Fantastic Beasts The Crimes of Grindelwald' Sneak Peek
# Predicted: real | Actual: real
#
# Sentence: Jennifer Garner Claims Tabloids Created "Trouble" In Her Marriage To Ben Affleck
# Predicted: real | Actual: fake
#
# Sentence: Carrie Underwood and Brad Paisley Will Host the 52nd Annual CMA Awards
# Predicted: real | Actual: real
#
# Sentence: Janelle Monae's "PYNK" Video Teaches an Accurate Lesson on Vagina Anatomy
# Predicted: real | Actual: real
#
# Sentence: Ian Somerhalder and Paul Wesley had a Vampire Diaries reunion
# Predicted: real | Actual: real
#
# Sentence: Can the The Voice winner Chloe Kohanski be the shows first real superstar?
# Predicted: real | Actual: real
#
# Sentence: Star Wars The Last Jedis celebrity cameos you may have missed update
# Predicted: real | Actual: real
#
# Sentence: Travis Scott, Kylie Jenners Boyfriend Split Rumors No Break Up
# Predicted: fake | Actual: fake
#
# Sentence: A look at the unforgettable moment Prince Charles walked Meghan Markle down the aisle
# Predicted: real | Actual: real
#
# Sentence: A Teen Bradley Cooper Wrote An Article About Hooking Up With His BFF
# Predicted: fake | Actual: real
#
# Sentence: Diane Kruger's new movie won the Golden Globe for best foreign film and it was so emotionally devastating she couldn't work for 6 months
# Predicted: real | Actual: real
#
# Sentence: Kylie Jenner is pregnant, according to reports
# Predicted: real | Actual: real
#
# Sentence: Trump tax returns Celebrities react on social media
# Predicted: fake | Actual: fake
#
# Sentence: Flashback Alert! Relive These AListers First MTV Movie Awards
# Predicted: real | Actual: real
#
# Sentence: 26 Things You Didn't See on TV at the 2018 ACM Awards
# Predicted: real | Actual: real
#
# Sentence: Scott Wolf, 50, of Party Of Five shows off insane six pack abs as he adds 'you bet your a I did'
# Predicted: real | Actual: real
#
# Sentence: Gwen Stefani and Blake Shelton Put Baby, Wedding Plans on Hold
# Predicted: real | Actual: fake
#
# Sentence: People's Choice Awards 2018 See the full list of nominees
# Predicted: real | Actual: real
#
# Sentence: Beyonce and JayZ Building Million Dollar Nursery For Twins?
# Predicted: fake | Actual: fake
#
# Sentence: How Beauty and the Beast's Belle Made This Young Girl's Dreams Come True Prepare to Grab Some Tissues
# Predicted: real | Actual: real
#
# Sentence: Guillermo del Toro Approves of Natalie Portmans AllMale Nominees Comment
# Predicted: real | Actual: real
#
# Sentence: Oscars "In Memoriam" Garry Shandling, Robert Vaughn Among Snubs
# Predicted: real | Actual: fake
#
# Sentence: 'Twin Girls' North West Penelope Disick Wear Matching Outfits at UnicornThemed Birthday Bash
# Predicted: real | Actual: real
#
# Sentence: Abby Lee Millers Life in Prison She Completed These Classes
# Predicted: real | Actual: real
#
# Sentence: Ultimate Betrayal! Jennifer Anistons BFF Is Still Hanging With Justin Theroux
# Predicted: fake | Actual: fake
#
# Sentence: Meghan Markle Wore the Queens Favorite Nail Polish On Her Wedding Day
# Predicted: real | Actual: real
#
# Sentence: "I want to have his babies" Kristen reveals family plans with Rob just weeks before she cheated
# Predicted: fake | Actual: fake
#
# Sentence: Chris Harrison on His Next Big Step and If We'll Get Another Bachelor Out of 'Paradise' Exclusive
# Predicted: real | Actual: real
#
# Sentence: Taylor swift fakes a friendship with russell westbrook in silly nba awards video
# Predicted: fake | Actual: real
#
# Sentence: Catherine, Duchess of Cambridge
# Predicted: real | Actual: real
#
# Sentence: 11 cringe moments from Kim and Kanye's Celebrity Family Feud appearance
# Predicted: real | Actual: real
#
# Sentence: Tiffany Haddish's 2018 Oscars Gown Is Inspired by Her Late Father
# Predicted: real | Actual: real
#
# Sentence: Kim Kardashian Is Considering Leaving Kanye West After His Latest Outburst "It's Over" EXCLUSIVE
# Predicted: fake | Actual: fake
#
# Sentence: Watch Kelly Ripa Hilariously Audition For American Idol
# Predicted: real | Actual: real
#
# Sentence: Paris Jackson goes casual in sweats at Daily Front Row Fashion Media Awards during NYFW
# Predicted: real | Actual: real
#
# Sentence: Netflix Will Stop Streaming Marvel Movies
# Predicted: fake | Actual: real
#
# Sentence: R. Kelly Scandals From Aaliyah to Alleged Cults Rolling Stone BJO
# Predicted: real | Actual: real
#
# Sentence: George Takei Accused of Sexually Assaulting Former Model in 1981
# Predicted: real | Actual: real
#
# Sentence: Scooter Braun Claims Justin Bieber's Struggles Were 'Worse Than People Realized' 'It Was a Problem'
# Predicted: real | Actual: real
#
# Sentence: Sterling K. Browns Golden Globes Speech Was So, So Moving Just Like Everything Else He Does
# Predicted: real | Actual: real
#
# Sentence: Here's How Keith Urban and Nicole Kidman Are Spending the Holidays
# Predicted: real | Actual: real
#
# Sentence: Relive 10 Musical Numbers From A Christmas Story Live!
# Predicted: real | Actual: real
#
# Sentence: Ashley Iaconetti Kevin Wendt Open Up About Split
# Predicted: real | Actual: real
#
# Sentence: Are Demi Moore And Ed Helms Dating? New Details On Their Rumored Secret Relationship
# Predicted: fake | Actual: fake
#
# Sentence: 'The Voice' 10 Things We Know About Gwen Stefani and Blake Shelton's Relationship
# Predicted: real | Actual: fake
#
# Sentence: Better Call Saul
# Predicted: real | Actual: real
#
# Sentence: Honey Boo Boo Says Her Dad BodyShamed Her as Mama June Runs Down Sugar Bear's Shocking Behavior
# Predicted: real | Actual: real
#
# Sentence: Get Your First Look at Doctor Strange in the Japanese Thor Ragnarok Trailer
# Predicted: real | Actual: real
#
# Sentence: 'Fifty Shades Freed' trailer teases more sex, more dangerous threats Video
# Predicted: real | Actual: real
#
# Sentence: International Energy Statistics
# Predicted: real | Actual: real
#
# Sentence: The Best Years
# Predicted: real | Actual: real
#
# Sentence: WATCH First Trailer for Bobbi Kristina Brown TV Biopic
# Predicted: real | Actual: real
#
# Sentence: Married at First Sight star is stunned after wife reveals she is pregnant
# Predicted: real | Actual: real
#
# Sentence: Gwen Stefani Gushes Over Her "Cute Blakey" Shelton "You Changed My Life"
# Predicted: real | Actual: real
#
# Sentence: Elizabeth Olsen and Robbie Arnett make debut at Emmy party
# Predicted: real | Actual: real
#
# Sentence: Celebrity Holiday Cards 2017 The Currys, Kardashians More Send Seasons Greetings
# Predicted: real | Actual: fake
#
# Sentence: Michael Jackson speaks BEYOND THE GRAVE to reveal TRUTH about death
# Predicted: fake | Actual: real
#
# Sentence: Kim Kardashian Furious With Travis Scott For Neglecting Pregnant Kylie Jenner
# Predicted: fake | Actual: fake
#
# Sentence: Why Billy Bob Thornton Divorced Angelina Jolie After 'Great' Marriage
# Predicted: real | Actual: real
#
# Sentence: Ronnie OrtizMagro Reveals Name of Newborn Daughter
# Predicted: real | Actual: real
#
# Sentence: Stranger Things Kids Refuse to Give Any Season 3 Spoilers 'We All Die,' Noah Schnapp Jokes
# Predicted: real | Actual: real
#
# Sentence: Reasons Gwen and Blake's relationship is totally fake
# Predicted: fake | Actual: fake
#
# Sentence: Seagram's heiress nabbed in NXIVM sex cult arrests 'Smallville' star Allison Mack faces more charges
# Predicted: real | Actual: real
#
# Sentence: Selena Gomez Rises From the Ashes With Emotional 2017 American Music Awards Performance Parker XL
# Predicted: real | Actual: real
#
# Sentence: Blake Shelton Calls Meeting Gwen Stefani 'a Miracle' After 'Hitting Rock Bottom'
# Predicted: real | Actual: fake
#
# Sentence: Callie Torres
# Predicted: real | Actual: real
#
# Sentence: Sofia Richie
# Predicted: real | Actual: real
#
# Sentence: Alec Baldwin Seth Meyers NOT At War At Despite Report
# Predicted: fake | Actual: fake
#
# Sentence: Harry Styles raised over 1.2m for charity during his world tour
# Predicted: real | Actual: real
#
# Sentence: Restaurant review Stanleys gets a second look and comes up smelling of roses
# Predicted: real | Actual: fake
#
# Sentence: Queer Eyes Karamo Brown Engaged to Ian Jordan
# Predicted: real | Actual: real
#
# Sentence: 5YearOld Gets Wedding Wish Ahead of Heart Surgery
# Predicted: real | Actual: real
#
#
# Evaluation Metrics:
# Accuracy: 0.840000
# Precision: 0.803571
# Recall: 0.723684
# F1-score: 0.750000
# Processing Time (s): 53.877705
# Total Cost ($): 0.534496
# Cost per Classification ($): 0.005345
# Total Tokens Used: 267248.000000
# Average Tokens per Article: 2672.480000

# %%
# GPT 4O
Evaluation Metrics:
Accuracy: 0.860000
Precision: 0.808114
Recall: 0.808114
F1-score: 0.808114
Processing Time (s): 77.320774
Total Cost ($): 0.664002
Cost per Classification ($): 0.006640
Total Tokens Used: 263501.000000
Average Tokens per Article: 2635.010000


# GPT 4-TURBO
Evaluation Metrics:
Accuracy: 0.670000
Precision: 0.654958
Recall: 0.711623
F1-score: 0.639699
Processing Time (s): 100.285479
Total Cost ($): 2.686480
Cost per Classification ($): 0.026865
Total Tokens Used: 267248.000000
Average Tokens per Article: 2672.480000


# GPT 3.5-TURBO
Evaluation Metrics:
Accuracy: 0.840000
Precision: 0.803571
Recall: 0.723684
F1-score: 0.750000
Processing Time (s): 66.873411
Total Cost ($): 0.534496
Cost per Classification ($): 0.005345
Total Tokens Used: 267248.000000
Average Tokens per Article: 2672.480000

# %%
##################
# CLASSIFICATION #
##################
Accuracy = Number of correct predictions/Total predictions

Precision = TP / (TP+ FP)
# How many predicted fake headlines are actually fake
# Low precision means model is mislabelling too many real headlines as fake

Recall = TP / (TP + FN)
# How many fake headlines were correctly identified as fake
# Low recall means model is letting too many fake news headlines slip through as real

F1 = 2 X (Precision x Recall)/(Precision + Recall) #Harmonic mean of precision and recall

##############
# EFFICIENCY #
##############
Tokens per article = How many tokens the LLM processes per request = Total tokens/Number of Sentences
Cost per classification = Total cost/Number of Sentences

#############
# TECHNICAL #
#############
Processing time = How long it takes to run
Cross-dataset performance = Compare performance on different datasets
